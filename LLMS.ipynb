# %%
from datasets import load_dataset
task_list = ['accounting'] # 載入資料名稱

for task in task_list:
    test = load_dataset('ikala/tmmluplus', task)['test']

# %%
import pandas as pd
df = pd.DataFrame(test) # 轉成DataFrame
df.tail() # 末五筆資料
# Out:
#                                               question  \
# 186  甲公司以帳面金額為 1 千萬元之土地，提早清償帳面價值為 1 千 3 百萬元之應付票據，於清...
# 187  甲公司於 X2 年初按公允價值$1,000,000 將一部機器出售給乙公司，該機器原始成本 ...
# 188  康橋公司於 X5 年初付現$1,500,000 及開立 3 年期面額$3,000,000 的...
# 189  甲公司 X2 年 1 月 1 日流通在外普通股為 200,000 股，X2 年 4 月 1 ...
# 190  甲投資公司利用融券帳戶，於111年1月1日以市價$100融券賣出乙公司股票10,000股，並...
#
#                                     A  \
# 186                    認列處分土地利益 3 百萬元
# 187                         $(14,640)
# 188                        $3,234,678
# 189                         203,150 股
# 190  甲投資公司此項融券交易使112年度的稅前淨利增加$100,000
#
#                                            B  \
# 186                           認列債務清償利益 3 百萬元
# 187                                  $73,200
# 188                               $3,512,626
# 189                                202,850 股
# 190  甲投資公司111年12月31日持有供交易之金融負債的餘額為$1,000,000
#
#                                     C  \
# 186                        無須認列處分土地損益
# ...
